# %%
import torch
import torch.nn as nn
from PIL import Image
from torchvision import transforms
import os
import sys
os.chdir('../')
sys.path.append('./')
os.getcwd()
from utils import get_psnr, image_normalization
from model import DeepJSCC
import matplotlib.pyplot as plt
import matplotlib
from tensorboard.backend.event_processing import event_accumulator, event_multiplexer
import pandas as pd

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %% [markdown]
# ### For SNR

# %%
log_dir = './out/eval/'
ea = event_multiplexer.EventMultiplexer().AddRunsFromDirectory(log_dir)

# %%
ratio_float = "{:.2f}".format(eval("1/6"))
log_dir = './out/eval/'
tag = 'psnr'
ea = event_multiplexer.EventMultiplexer().AddRunsFromDirectory(log_dir)
ea.Reload()

dataset_name = 'cifar10'
ratio ='1 / 12'
channel = 'AWGN'
alpha = 1
markers = ['o', 's', 'D', '|', '*', '1']


for run in sorted(ea.Runs().keys(), key=lambda x: float(x.split('_')[2]) if '(' not in x else float(100)):
    if (dataset_name or dataset_name.upper() in run.split('_')) and (ratio_float in run.split('_')) and (channel in run.split('_') or channel.upper() in run.split('_')):
        snr = int(float(run.split('_')[2])) if '(' not in run else '(1-19)'
        print(r'Deep JSCC(${\text{SNR}_{\text{train}}}$)'+f'={str(snr)}dB')
# Out:
# Deep JSCC(${\text{SNR}_{\text{train}}}$)=1dB
# Deep JSCC(${\text{SNR}_{\text{train}}}$)=4dB
# Deep JSCC(${\text{SNR}_{\text{train}}}$)=7dB
# Deep JSCC(${\text{SNR}_{\text{train}}}$)=13dB
# Deep JSCC(${\text{SNR}_{\text{train}}}$)=19dB
# Deep JSCC(${\text{SNR}_{\text{train}}}$)=(1-19)dB

# %%
def plot_snr(dataset_name, ratio, ea, channel, alpha = 1):
        
    ratio_float = "{:.2f}".format(eval(ratio))
    log_dir = './out/eval/'
    tag = 'psnr'
    ea = event_multiplexer.EventMultiplexer().AddRunsFromDirectory(log_dir)
    ea.Reload()
    markers = ['o', 's', 'D', '|', '*', '1']
    index = 0
    plt.figure(figsize=(7.5,6))
    for run in sorted(ea.Runs().keys(), key=lambda x: float(x.split('_')[2]) if '(' not in x else float(100)):
        if (dataset_name or dataset_name.upper() in run.split('_')) and (ratio_float in run.split('_')) and (channel in run.split('_') or channel.upper() in run.split('_')):
            snr = int(float(run.split('_')[2])) if '(' not in run else '(1-19)'
            sc = ea.Scalars(run, tag)
            df = pd.Series(data=[s.value for s in sc], index=[s.step for s in sc])
            smooth = df.ewm(alpha = alpha).mean()

            label = r'Deep JSCC(${\text{SNR}_{\text{train}}}$)'+f'={str(snr)}dB'

            plt.plot([s for s in smooth.index], [s for s in smooth.values], label=label,linewidth=1.8,
                                marker = markers[index], markerfacecolor = 'None', markersize = 10 if markers[index]=='|' else 6, markeredgewidth = 2.1, markevery = 4)
                
            # plt.plot([s for s in smooth.index][::15], [s for s in smooth.values][::15], linestyle = 'None',
            #         marker = markers[index], color = line[0].get_color(), markerfacecolor = 'None', markersize=8, markeredgewidth = 1.5)
            index += 1
            
            
            
    plt.legend(prop={'size': 13})
        

    plt.xlabel(r'$\text{SNR}_\text{test} (dB)$',fontsize = 14) 
    plt.ylabel('PSNR (dB)',fontsize = 14)
    plt.title('PSNR in {}, ratio = {}, on {} channel type'.format(dataset_name.upper(), ratio, channel),fontsize = 14)
    # plt.title('Test Accuracy in ' + dataset_name.upper())
    plt.xlim(-1, 26)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.grid()
    plt.show()

# %%
dataset_name = 'cifar10'
ratio ='1 / 12'
channel = 'AWGN'
plot_snr(dataset_name, ratio, ea, channel)

# %%
dataset_name = 'cifar10'
ratio ='1 / 6'
channel = 'AWGN'
plot_snr(dataset_name, ratio, ea, channel)

# %%
dataset_name = 'cifar10'
ratio ='1 / 6'
channel = 'Rayleigh'
plot_snr(dataset_name, ratio, ea, channel, alpha = 0.3)
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_10944\3711204464.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={'size': 13})

# %%
dataset_name = 'cifar10'
ratio ='1 / 3'
channel = 'Rayleigh'
plot_snr(dataset_name, ratio, ea, channel, alpha = 0.3)
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_10944\3711204464.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={'size': 13})
